# %%
import pandas as pd
from tabulate import tabulate

# %%
csv_file_path = 'Systolic1.csv' 
df = pd.read_csv(csv_file_path)
df.head(10).style\
    .set_table_styles(
        [{'selector': 'th', 'props': [('background-color', '#5CAF50'), ('color', 'white')]}]
    )\
    .set_properties(**{'border': '1px solid black', 'padding': '8px'})\
    .background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_8f796 th {
#   background-color: #5CAF50;
#   color: white;
# }
# #T_8f796_row0_col0 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_8f796_row0_col1 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_8f796_row0_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_8f796_row1_col0 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_8f796_row1_col1 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_8f796_row1_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_8f796_row2_col0 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_8f796_row2_col1 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_8f796_row2_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #70c274;
#   color: #000000;
# }
# #T_8f796_row3_col0 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_8f796_row3_col1 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_8f796_row3_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_8f796_row4_col0 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_8f796_row4_col1 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_8f796_row4_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_8f796_row5_col0, #T_8f796_row5_col1, #T_8f796_row5_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8f796_row6_col0 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_8f796_row6_col1 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_8f796_row6_col2, #T_8f796_row7_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #99d595;
#   color: #000000;
# }
# #T_8f796_row7_col0 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_8f796_row7_col1 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_8f796_row8_col0 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_8f796_row8_col1 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_8f796_row8_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_8f796_row9_col0, #T_8f796_row9_col1, #T_8f796_row9_col2 {
#   border: 1px solid black;
#   padding: 8px;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_8f796">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f796_level0_col0" class="col_heading level0 col0" >X1</th>
#       <th id="T_8f796_level0_col1" class="col_heading level0 col1" >X2</th>
#       <th id="T_8f796_level0_col2" class="col_heading level0 col2" >X3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f796_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f796_row0_col0" class="data row0 col0" >132</td>
#       <td id="T_8f796_row0_col1" class="data row0 col1" >52</td>
#       <td id="T_8f796_row0_col2" class="data row0 col2" >173</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8f796_row1_col0" class="data row1 col0" >143</td>
#       <td id="T_8f796_row1_col1" class="data row1 col1" >59</td>
#       <td id="T_8f796_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8f796_row2_col0" class="data row2 col0" >153</td>
#       <td id="T_8f796_row2_col1" class="data row2 col1" >67</td>
#       <td id="T_8f796_row2_col2" class="data row2 col2" >194</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f796_row3_col0" class="data row3 col0" >162</td>
#       <td id="T_8f796_row3_col1" class="data row3 col1" >73</td>
#       <td id="T_8f796_row3_col2" class="data row3 col2" >211</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8f796_row4_col0" class="data row4 col0" >154</td>
#       <td id="T_8f796_row4_col1" class="data row4 col1" >64</td>
#       <td id="T_8f796_row4_col2" class="data row4 col2" >196</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8f796_row5_col0" class="data row5 col0" >168</td>
#       <td id="T_8f796_row5_col1" class="data row5 col1" >74</td>
#       <td id="T_8f796_row5_col2" class="data row5 col2" >220</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8f796_row6_col0" class="data row6 col0" >137</td>
#       <td id="T_8f796_row6_col1" class="data row6 col1" >54</td>
#       <td id="T_8f796_row6_col2" class="data row6 col2" >188</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8f796_row7_col0" class="data row7 col0" >149</td>
#       <td id="T_8f796_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_8f796_row7_col2" class="data row7 col2" >188</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8f796_row8_col0" class="data row8 col0" >159</td>
#       <td id="T_8f796_row8_col1" class="data row8 col1" >65</td>
#       <td id="T_8f796_row8_col2" class="data row8 col2" >207</td>
#     </tr>
#     <tr>
#       <th id="T_8f796_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8f796_row9_col0" class="data row9 col0" >128</td>
#       <td id="T_8f796_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_8f796_row9_col2" class="data row9 col2" >167</td>
#     </tr>
#   </tbody>
# </table>
